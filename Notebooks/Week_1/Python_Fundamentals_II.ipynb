# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'D:\ACADEMICS\SEMESTER 3\Data_Analytics_With_Python\Data_analytics\Data\gapminder.tsv', sep='\t')

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
print(df.head())
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
print(df.tail(n=1))
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
print(df.loc[[2,22,99]])
# Out:
#         country continent  year  lifeExp       pop    gdpPercap
# 2   Afghanistan      Asia  1962   31.997  10267083   853.100710
# 22      Albania    Europe  2002   75.651   3508512  4604.211737
# 99   Bangladesh      Asia  1967   43.453  62821884   721.186086

# %%
print(df.iloc[1])
# Out:
# country      Afghanistan
# continent           Asia
# year                1957
# lifeExp           30.332
# pop              9240934
# gdpPercap      820.85303
# Name: 1, dtype: object

# %%
print(df.iloc[-1])  
#print from end
#-1 can be used in iloc only not loc
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
subset= df.loc[:, ['country','continent','lifeExp']]
print(subset.head())
# Out:
#        country continent  lifeExp
# 0  Afghanistan      Asia   28.801
# 1  Afghanistan      Asia   30.332
# 2  Afghanistan      Asia   31.997
# 3  Afghanistan      Asia   34.020
# 4  Afghanistan      Asia   36.088

# %%
range= list(range(5))
print(df.iloc[:,range].head())
# Out:
#        country continent  year  lifeExp       pop
# 0  Afghanistan      Asia  1952   28.801   8425333
# 1  Afghanistan      Asia  1957   30.332   9240934
# 2  Afghanistan      Asia  1962   31.997  10267083
# 3  Afghanistan      Asia  1967   34.020  11537966
# 4  Afghanistan      Asia  1972   36.088  13079460

# %%
print(df.loc[3,'country'])
# Out:
# Afghanistan

# %%
print(df.iloc[[0,99,65],[0,2.3]])
# Out:
#         country  year
# 0   Afghanistan  1952
# 99   Bangladesh  1967
# 65    Australia  1977

# %%
print(df.loc[1:6,'country':'pop'])
# Out:
#        country continent  year  lifeExp       pop
# 1  Afghanistan      Asia  1957   30.332   9240934
# 2  Afghanistan      Asia  1962   31.997  10267083
# 3  Afghanistan      Asia  1967   34.020  11537966
# 4  Afghanistan      Asia  1972   36.088  13079460
# 5  Afghanistan      Asia  1977   38.438  14880372
# 6  Afghanistan      Asia  1982   39.854  12881816

# %%
avg_lifeExp= df.groupby('year')['lifeExp'].mean()
avg_lifeExp
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
'''                             Average salary per department
                            df.groupby('Department')['Salary'].mean()                               '''


multi_grp_var= df.groupby(['year','country'])[['lifeExp','lifeExp']].mean()
print(multi_grp_var.to_string())
#use .to_string() to print full dataset without truncated .....
# Out:
#                                 lifeExp   lifeExp
# year country
# 1952 Afghanistan               28.80100  28.80100
#      Albania                   55.23000  55.23000
#      Algeria                   43.07700  43.07700
#      Angola                    30.01500  30.01500
#      Argentina                 62.48500  62.48500
#      Australia                 69.12000  69.12000
#      Austria                   66.80000  66.80000
#      Bahrain                   50.93900  50.93900
#      Bangladesh                37.48400  37.48400
#      Belgium                   68.00000  68.00000
#      Benin                     38.22300  38.22300
#      Bolivia                   40.41400  40.41400
#      Bosnia and Herzegovina    53.82000  53.82000
#      Botswana                  47.62200  47.62200
#      Brazil                    50.91700  50.91700
#      Bulgaria                  59.60000  59.60000
#      Burkina Faso              31.97500  31.97500
# ...

# %%
'''Flattening of data means converting data from a nested or hierarchical structure into a flat,
two-dimensional structure — typically a table where each row is an individual record and each column is a single attribute.'''
flat= multi_grp_var.reset_index()
print(flat.head(15))
# Out:
#     year                 country  lifeExp  lifeExp
# 0   1952             Afghanistan   28.801   28.801
# 1   1952                 Albania   55.230   55.230
# 2   1952                 Algeria   43.077   43.077
# 3   1952                  Angola   30.015   30.015
# 4   1952               Argentina   62.485   62.485
# 5   1952               Australia   69.120   69.120
# 6   1952                 Austria   66.800   66.800
# 7   1952                 Bahrain   50.939   50.939
# 8   1952              Bangladesh   37.484   37.484
# 9   1952                 Belgium   68.000   68.000
# 10  1952                   Benin   38.223   38.223
# 11  1952                 Bolivia   40.414   40.414
# 12  1952  Bosnia and Herzegovina   53.820   53.820
# 13  1952                Botswana   47.622   47.622
# 14  1952                  Brazil   50.917   50.917

# %%
'''    The .nunique() function returns the number of unique (distinct) values in a Series or DataFrame.   '''
unique= df.groupby('continent')['country'].nunique()
unique
'''How many unique countries are there in each continent?'''
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
avg_lifeExp.plot()
# Out:
# <Axes: xlabel='year'>
